# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/en/d09_weight_banding.ipynb)
#
# # D09 Weight Banding
#
# Analyze the final classifier weight matrix live: reorder classes and channels, visualize bands, and compare against shuffled baselines.
#
# ## Notebook Scope
#
# This notebook treats banding as a live weight-analysis problem on the public classifier head rather than a static export of a finished figure.
#
# ## Live Sections
#
# - Final-layer weight-matrix reordering
# - Band-span versus shuffled-baseline measurements
# - Candidate class-group inspection from the reordered matrix
#
# ## Integrity Note
#
# The matrix views and banding scores are computed live from the public classifier head. This is a runtime analysis notebook, not a bundled static export.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
plot_d09_weight_banding()

# %% [markdown]
# ## Wrap-up
#
# This notebook keeps **Weight Banding** inside a strict live-only contract: every plot and every measurement comes from runtime execution on public weights, public data, and generated stimuli.
