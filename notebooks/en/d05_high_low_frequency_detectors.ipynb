# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/en/d05_high_low_frequency_detectors.ipynb)
#
# # D05 High-Low Frequency Detectors
#
# Generate directional high-low frequency transitions live and measure which channels prefer these frequency edges.
#
# ## Notebook Scope
#
# The notebook synthesizes frequency-edge stimuli at runtime and searches for channels that respond strongly and selectively to them.
#
# ## Live Sections
#
# - High-low frequency stimulus generation
# - Channel search for frequency-edge preference
# - Orientation tuning for the best frequency detector
#
# ## Integrity Note
#
# The stimuli are generated live with simple public code. The resulting figures are runtime measurements, not bundled replicas of the Distill artwork.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
best_frequency_channel = plot_d05_frequency_detector_search()

# %%
plot_d05_frequency_tuning(best_frequency_channel)

# %% [markdown]
# ## Wrap-up
#
# This notebook keeps **High-Low Frequency Detectors** inside a strict live-only contract: every plot and every measurement comes from runtime execution on public weights, public data, and generated stimuli.
