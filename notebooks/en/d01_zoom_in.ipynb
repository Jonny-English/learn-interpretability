# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/en/d01_zoom_in.ipynb)
#
# # D01 Zoom In: An Introduction to Circuits
#
# Run a live visual-circuits walkthrough on InceptionV1: feature visualization, real-image validation, orientation tuning, and a small circuit trace.
#
# ## Notebook Scope
#
# This notebook keeps the article's intuition but rebuilds it with live public-stack outputs instead of pre-rendered figures.
#
# ## Live Sections
#
# - Activation maximization on representative channels
# - CIFAR-10 validation for a curve-preferring neuron
# - Orientation tuning on synthetic arc stimuli
# - A small upstream-weight trace for one mixed3b circuit
#
# ## Integrity Note
#
# This is a live public-stack reconstruction of the article's core moves. It does not claim to reproduce every bespoke figure or manual annotation from the Distill page.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
plot_d01_feature_gallery()

# %%
plot_d01_real_image_validation()

# %%
plot_d01_orientation_tuning()

# %%
plot_d01_small_circuit_trace()

# %% [markdown]
# ## Wrap-up
#
# This notebook keeps **Zoom In: An Introduction to Circuits** inside a strict live-only contract: every plot and every measurement comes from runtime execution on public weights, public data, and generated stimuli.
