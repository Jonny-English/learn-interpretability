# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/en/d04_equivariance.ipynb)
#
# # D04 Naturally Occurring Equivariance in Neural Networks
#
# Find transformed filter pairs live, compare rotated and translated responses, and inspect how feature families move together.
#
# ## Notebook Scope
#
# The notebook demonstrates equivariant structure by searching weight-space similarities and then validating them with stimulus sweeps.
#
# ## Live Sections
#
# - Rotation-similar filter-pair search in Inception branches
# - Rotated arc response sweeps for matched channels
# - Translated-stimulus response consistency checks
#
# ## Integrity Note
#
# This is a teaching-scale live analysis of equivariant structure in public InceptionV1 weights and activations, not a claim to reproduce every Distill case study.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
equivariance_pair = plot_d04_equivariance_search()

# %%
plot_d04_equivariance_responses(*equivariance_pair)

# %% [markdown]
# ## Wrap-up
#
# This notebook keeps **Naturally Occurring Equivariance in Neural Networks** inside a strict live-only contract: every plot and every measurement comes from runtime execution on public weights, public data, and generated stimuli.
