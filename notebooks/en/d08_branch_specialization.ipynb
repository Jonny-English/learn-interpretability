# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/en/d08_branch_specialization.ipynb)
#
# # D08 Branch Specialization
#
# Measure how different Inception branches respond to line, arc, and frequency families, then render branch-specific exemplars live.
#
# ## Notebook Scope
#
# The notebook studies specialization as a live branch-by-family response pattern rather than as a static diagram imported from the paper.
#
# ## Live Sections
#
# - Branch-wise response heatmap across stimulus families
# - Top-channel search inside each branch
# - Live feature renders for branch-specific exemplars
#
# ## Integrity Note
#
# The specialization story here comes from live measurements on public branches and stimuli. It is meant to be transparent and inspectable rather than exhaustively paper-faithful.

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
plot_d08_branch_specialization()

# %% [markdown]
# ## Wrap-up
#
# This notebook keeps **Branch Specialization** inside a strict live-only contract: every plot and every measurement comes from runtime execution on public weights, public data, and generated stimuli.
