# %% [markdown]
# [![在 Colab 中打开](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/zh/d09_weight_banding.ipynb)
#
# # D09 权重带状结构
#
# 实时分析最终分类器权重矩阵：重排行与列、可视化带状结构，并和打乱基线比较。
#
# ## Notebook 范围
#
# 这本 notebook 把带状结构当成公开分类头上的实时权重分析问题来做，而不是直接导出一张完成图。
#
# ## Live 内容
#
# - 最终层权重矩阵重排
# - 带宽跨度与打乱基线的比较
# - 从重排矩阵里检查候选类别分组
#
# ## 诚实边界
#
# 矩阵图和 banding 分数都直接从公开分类头实时计算而来。这是运行时分析 notebook，不是预先打包好的静态导出。

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
plot_d09_weight_banding()

# %% [markdown]
# ## 小结
#
# 这本 notebook 把 **权重带状结构** 保持在严格的 live-only 边界内：所有图和所有测量都来自公开权重、公开数据和运行时生成的刺激。
