# %% [markdown]
# [![在 Colab 中打开](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jonny-English/learn-interpretability/blob/main/notebooks/zh/d06_curve_circuits.ipynb)
#
# # D06 曲线电路
#
# 通过 live 的上游重要度、消融和最小代理模型，在 mixed3a 与 mixed3b 之间追踪一条曲线电路。
#
# ## Notebook 范围
#
# 这本 notebook 把一条曲线电路改写成公开栈可跑的 trace：找上游通道、做消融，再把真实目标响应和最小代理模型对比起来。
#
# ## Live 内容
#
# - 从 mixed3b 回溯到 mixed3a 的上游重要度搜索
# - 对最关键上游通道做消融
# - 最小代理模型与真实目标响应对比
#
# ## 诚实边界
#
# 这本 notebook 直接使用公开 InceptionV1 的实时权重、激活和消融结果。它是教学尺度的 circuit trace，不是 Distill 原文所有工件的完整重建。

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/Jonny-English/learn-interpretability.git"
REPO_DIR = "learn-interpretability"
REPO_BRANCH = "main"

if "google.colab" in sys.modules:
    candidate = Path("/content") / REPO_DIR
    if not candidate.exists():
        subprocess.run(
            ["git", "clone", "--depth", "1", "--branch", REPO_BRANCH, REPO_URL, str(candidate)],
            check=True,
        )
    os.chdir(candidate)

root = Path.cwd().resolve()
while not (root / "content" / "course.json").exists():
    if root.parent == root:
        raise RuntimeError("Run this notebook from the repository root.")
    root = root.parent

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "torchvision", "torch-lucent", "matplotlib", "numpy", "Pillow"],
        check=True,
    )

from utils.distill_circuits import *

set_seed(0)
describe_runtime()

# %%
plot_d06_curve_circuit()

# %% [markdown]
# ## 小结
#
# 这本 notebook 把 **曲线电路** 保持在严格的 live-only 边界内：所有图和所有测量都来自公开权重、公开数据和运行时生成的刺激。
